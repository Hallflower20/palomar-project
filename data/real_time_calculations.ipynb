# %%
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import astropy.units as u
import astropy.constants as c
from astropy.table import Table
import numpy as np
from matplotlib import colors
import lmfit
import glob
from lmfit.models import GaussianModel, SplineModel, PolynomialModel

# %%
def plot_data(obj,percentile = [1, 99.99],use_log = False):
    if(use_log):
        plt.imshow(obj, origin='lower', cmap='gray', clim=(np.percentile(obj,percentile[0]), np.percentile(obj,percentile[1])),norm=colors.LogNorm())
    else:
        plt.imshow(obj, origin='lower', cmap='gray', clim=(np.percentile(obj,percentile[0]), np.percentile(obj,percentile[1])))
    plt.colorbar()

# %%
files = glob.glob("./20230507/*.fits")
files = np.sort(files)

# %%
chosen_file = files[0]
open_file = fits.open(chosen_file)
header_file = open_file[0].header
print(repr(header_file))
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2048 / length of data axis 1
# NAXIS2  =                 1024 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format defined in Astronomy and
# COMMENT   Astrophysics Supplement Series v44/p363, v44/p371, v73/p359, v73/p365.
# COMMENT   Contact the NASA Science Office of Standards and Technology for the
# COMMENT   FITS Definition document #100 and other FITS information.
# OBJECT  = 'lampon  '           / object name
# SOFTVER = '4.0     '           / software version
# HDR_REV = '4.3     '           / header revision
# OBSERVER= 'xanderberylcarlos'  / observer
# OBSTYPE = 'flat    '           / observation type
# UTSHUT  = '2023-05-06T23:32:08.151' / UT shutter open
# COADDS  =                    1 / number of coadded images
# FSAMPLE =                    1 / number of fowler samples
# EXPTIME =                  45. / exposure time
# ACCTIME = '        '           / accumulated exp time (sur)
# NAMPSXY = '9 8     '           / number of amplifiers in x y
# ASEC1   = '[1025:2048,1:128]'  / amplifier section 1(LL)
# BSEC1   = '        '           / bias section 1(LL)
# CSEC1   = '[1025:2048,1:128]'  / ccd section 1(LL)
# DSEC1   = '[1025:2048,1:128]'  / data section 1(LL)
# TSEC1   = '[1025:2048,1:128]'  / trim section 1(LL)
# ASEC2   = '[1025:2048,129:256]' / amplifier section 2(LL)
# BSEC2   = '        '           / bias section 2(LL)
# CSEC2   = '[1025:2048,129:256]' / ccd section 2(LL)
# DSEC2   = '[1025:2048,129:256]' / data section 2(LL)
# TSEC2   = '[1025:2048,129:256]' / trim section 2(LL)
# ASEC3   = '[1025:2048,257:384]' / amplifier section 3(LL)
# BSEC3   = '        '           / bias section 3(LL)
# CSEC3   = '[1025:2048,257:384]' / ccd section 3(LL)
# DSEC3   = '[1025:2048,257:384]' / data section 3(LL)
# TSEC3   = '[1025:2048,257:384]' / trim section 3(LL)
# ASEC4   = '[1025:2048,385:512]' / amplifier section 4(LL)
# BSEC4   = '        '           / bias section 4(LL)
# CSEC4   = '[1025:2048,385:512]' / ccd section 4(LL)
# DSEC4   = '[1025:2048,385:512]' / data section 4(LL)
# TSEC4   = '[1025:2048,385:512]' / trim section 4(LL)
# ASEC5   = '[1025:2048,513:640]' / amplifier section 5(LL)
# BSEC5   = '        '           / bias section 5(LL)
# CSEC5   = '[1025:2048,513:640]' / ccd section 5(LL)
# DSEC5   = '[1025:2048,513:640]' / data section 5(LL)
# TSEC5   = '[1025:2048,513:640]' / trim section 5(LL)
# ASEC6   = '[1025:2048,641:768]' / amplifier section 6(LL)
# BSEC6   = '        '           / bias section 6(LL)
# CSEC6   = '[1025:2048,641:768]' / ccd section 6(LL)
# DSEC6   = '[1025:2048,641:768]' / data section 6(LL)
# TSEC6   = '[1025:2048,641:768]' / trim section 6(LL)
# ASEC7   = '[1025:2048,769:896]' / amplifier section 7(LL)
# BSEC7   = '        '           / bias section 7(LL)
# CSEC7   = '[1025:2048,769:896]' / ccd section 7(LL)
# DSEC7   = '[1025:2048,769:896]' / data section 7(LL)
# TSEC7   = '[1025:2048,769:896]' / trim section 7(LL)
# ASEC8   = '[1025:2048,897:1024]' / amplifier section 8(LL)
# BSEC8   = '        '           / bias section 8(LL)
# CSEC8   = '[1025:2048,897:1024]' / ccd section 8(LL)
# DSEC8   = '[1025:2048,897:1024]' / data section 8(LL)
# TSEC8   = '[1025:2048,897:1024]' / trim section 8(LL)
# ASEC9   = '[897:1024,1:1024]'  / amplifier section 9(UR)
# BSEC9   = '        '           / bias section 9(UR)
# CSEC9   = '[897:1024,1:1024]'  / ccd section 9(UR)
# DSEC9   = '[897:1024,1:1024]'  / data section 9(UR)
# TSEC9   = '[897:1024,1:1024]'  / trim section 9(UR)
# ASEC10  = '[769:896,1:1024]'   / amplifier section 10(UR)
# BSEC10  = '        '           / bias section 10(UR)
# CSEC10  = '[769:896,1:1024]'   / ccd section 10(UR)
# DSEC10  = '[769:896,1:1024]'   / data section 10(UR)
# TSEC10  = '[769:896,1:1024]'   / trim section 10(UR)
# ASEC11  = '[641:768,1:1024]'   / amplifier section 11(UR)
# BSEC11  = '        '           / bias section 11(UR)
# CSEC11  = '[641:768,1:1024]'   / ccd section 11(UR)
# DSEC11  = '[641:768,1:1024]'   / data section 11(UR)
# TSEC11  = '[641:768,1:1024]'   / trim section 11(UR)
# ASEC12  = '[513:640,1:1024]'   / amplifier section 12(UR)
# BSEC12  = '        '           / bias section 12(UR)
# CSEC12  = '[513:640,1:1024]'   / ccd section 12(UR)
# DSEC12  = '[513:640,1:1024]'   / data section 12(UR)
# TSEC12  = '[513:640,1:1024]'   / trim section 12(UR)
# ASEC13  = '[385:512,1:1024]'   / amplifier section 13(UR)
# BSEC13  = '        '           / bias section 13(UR)
# CSEC13  = '[385:512,1:1024]'   / ccd section 13(UR)
# DSEC13  = '[385:512,1:1024]'   / data section 13(UR)
# TSEC13  = '[385:512,1:1024]'   / trim section 13(UR)
# ASEC14  = '[257:384,1:1024]'   / amplifier section 14(UR)
# BSEC14  = '        '           / bias section 14(UR)
# CSEC14  = '[257:384,1:1024]'   / ccd section 14(UR)
# DSEC14  = '[257:384,1:1024]'   / data section 14(UR)
# TSEC14  = '[257:384,1:1024]'   / trim section 14(UR)
# ASEC15  = '[129:256,1:1024]'   / amplifier section 15(UR)
# BSEC15  = '        '           / bias section 15(UR)
# CSEC15  = '[129:256,1:1024]'   / ccd section 15(UR)
# DSEC15  = '[129:256,1:1024]'   / data section 15(UR)
# TSEC15  = '[129:256,1:1024]'   / trim section 15(UR)
# ASEC16  = '[1:128,1:1024]'     / amplifier section 16(UR)
# BSEC16  = '        '           / bias section 16(UR)
# CSEC16  = '[1:128,1:1024]'     / ccd section 16(UR)
# DSEC16  = '[1:128,1:1024]'     / data section 16(UR)
# TSEC16  = '[1:128,1:1024]'     / trim section 16(UR)
# ROISEC  = '[1:2048,1:1536]'    / roi section
# DEID_1  = 'Hawaii-IIb_47'      / detector ID_number
# DETSER_1= '47      '           / detector serial number
# FPA     = 'TSPEC_SPEC'         / focal plan array
# DHEINF  = 'SDSU, Gen-III'      / controller info
# QUADRANT= '3 and 4 '           / quadrants in use
# VOFF1   =                 -0.9 / video ch.1 offset
# VOFF9   =                 -0.9 / video ch.9 offset
# VBGAT_A =                  3.5 / bias gate A
# VBGAT_B =                  3.5 / bias gate B
# VBPOW_A =                   5. / bias power A
# VBPOW_B =                   5. / bias power B
# VRESET_A=                 0.75 / v reset A
# VRESET_B=                 0.75 / v reset B
# DSUB_A  =                   0. / d sub A
# DSUB_B  =                   0. / d sub B
# VDDA_A  =                   5. / analog power A
# VDDA_B  =                   5. / analog power B
# CATNAME = 'M17     '           / catalog name
# DATE    = '126     '           / date of obs
# TIME    = '23:32:08.2'         / time of obs
# LST     = '06:42:55.6'         / lst
# RA      = '06:41:18.93'        / ra
# DEC     = '+33:31:29.1'        / dec
# HA      = 'W00:00:06.2'        / ha
# AIRMASS =                   1. / airmass
# TELFOCUS=                30.78 / focus position mm
# CASS_ROT=               139.33 / cass rotation angle
# TELID   = '200     '           / telescope ID
# LODVER  = '/home/arcview/TSPEC/SPEC/config/DETECTOR/tim.lod' / timing board lod
# GAIN    =                  3.8 / e-/adu
# DISPAXIS= '1       '           / iraf dispersion axis

# %%
files[58]
# Out:
# './20230507/image0059.fits'

# %%
open_file = fits.open(files[58])
header_file = open_file[0].header
data_a = open_file['PRIMARY'].data.astype(float)
plot_data(data_a)
print(repr(header_file))
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2048 / length of data axis 1
# NAXIS2  =                 1024 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format defined in Astronomy and
# COMMENT   Astrophysics Supplement Series v44/p363, v44/p371, v73/p359, v73/p365.
# COMMENT   Contact the NASA Science Office of Standards and Technology for the
# COMMENT   FITS Definition document #100 and other FITS information.
# OBJECT  = 'B eclipse'          / object name
# SOFTVER = '4.0     '           / software version
# HDR_REV = '4.3     '           / header revision
# OBSERVER= 'xanderberyl'        / observer
# OBSTYPE = 'object  '           / observation type
# UTSHUT  = '2023-05-07T09:57:49.915' / UT shutter open
# COADDS  =                    1 / number of coadded images
# FSAMPLE =                   16 / number of fowler samples
# EXPTIME =                 300. / exposure time
# ACCTIME = '        '           / accumulated exp time (sur)
# NAMPSXY = '9 8     '           / number of amplifiers in x y
# ASEC1   = '[1025:2048,1:128]'  / amplifier section 1(LL)
# BSEC1   = '        '           / bias section 1(LL)
# CSEC1   = '[1025:2048,1:128]'  / ccd section 1(LL)
# DSEC1   = '[1025:2048,1:128]'  / data section 1(LL)
# TSEC1   = '[1025:2048,1:128]'  / trim section 1(LL)
# ASEC2   = '[1025:2048,129:256]' / amplifier section 2(LL)
# BSEC2   = '        '           / bias section 2(LL)
# CSEC2   = '[1025:2048,129:256]' / ccd section 2(LL)
# DSEC2   = '[1025:2048,129:256]' / data section 2(LL)
# TSEC2   = '[1025:2048,129:256]' / trim section 2(LL)
# ASEC3   = '[1025:2048,257:384]' / amplifier section 3(LL)
# BSEC3   = '        '           / bias section 3(LL)
# CSEC3   = '[1025:2048,257:384]' / ccd section 3(LL)
# DSEC3   = '[1025:2048,257:384]' / data section 3(LL)
# TSEC3   = '[1025:2048,257:384]' / trim section 3(LL)
# ASEC4   = '[1025:2048,385:512]' / amplifier section 4(LL)
# BSEC4   = '        '           / bias section 4(LL)
# CSEC4   = '[1025:2048,385:512]' / ccd section 4(LL)
# DSEC4   = '[1025:2048,385:512]' / data section 4(LL)
# TSEC4   = '[1025:2048,385:512]' / trim section 4(LL)
# ASEC5   = '[1025:2048,513:640]' / amplifier section 5(LL)
# BSEC5   = '        '           / bias section 5(LL)
# CSEC5   = '[1025:2048,513:640]' / ccd section 5(LL)
# DSEC5   = '[1025:2048,513:640]' / data section 5(LL)
# TSEC5   = '[1025:2048,513:640]' / trim section 5(LL)
# ASEC6   = '[1025:2048,641:768]' / amplifier section 6(LL)
# BSEC6   = '        '           / bias section 6(LL)
# CSEC6   = '[1025:2048,641:768]' / ccd section 6(LL)
# DSEC6   = '[1025:2048,641:768]' / data section 6(LL)
# TSEC6   = '[1025:2048,641:768]' / trim section 6(LL)
# ASEC7   = '[1025:2048,769:896]' / amplifier section 7(LL)
# BSEC7   = '        '           / bias section 7(LL)
# CSEC7   = '[1025:2048,769:896]' / ccd section 7(LL)
# DSEC7   = '[1025:2048,769:896]' / data section 7(LL)
# TSEC7   = '[1025:2048,769:896]' / trim section 7(LL)
# ASEC8   = '[1025:2048,897:1024]' / amplifier section 8(LL)
# BSEC8   = '        '           / bias section 8(LL)
# CSEC8   = '[1025:2048,897:1024]' / ccd section 8(LL)
# DSEC8   = '[1025:2048,897:1024]' / data section 8(LL)
# TSEC8   = '[1025:2048,897:1024]' / trim section 8(LL)
# ASEC9   = '[897:1024,1:1024]'  / amplifier section 9(UR)
# BSEC9   = '        '           / bias section 9(UR)
# CSEC9   = '[897:1024,1:1024]'  / ccd section 9(UR)
# DSEC9   = '[897:1024,1:1024]'  / data section 9(UR)
# TSEC9   = '[897:1024,1:1024]'  / trim section 9(UR)
# ASEC10  = '[769:896,1:1024]'   / amplifier section 10(UR)
# BSEC10  = '        '           / bias section 10(UR)
# CSEC10  = '[769:896,1:1024]'   / ccd section 10(UR)
# DSEC10  = '[769:896,1:1024]'   / data section 10(UR)
# TSEC10  = '[769:896,1:1024]'   / trim section 10(UR)
# ASEC11  = '[641:768,1:1024]'   / amplifier section 11(UR)
# BSEC11  = '        '           / bias section 11(UR)
# CSEC11  = '[641:768,1:1024]'   / ccd section 11(UR)
# DSEC11  = '[641:768,1:1024]'   / data section 11(UR)
# TSEC11  = '[641:768,1:1024]'   / trim section 11(UR)
# ASEC12  = '[513:640,1:1024]'   / amplifier section 12(UR)
# BSEC12  = '        '           / bias section 12(UR)
# CSEC12  = '[513:640,1:1024]'   / ccd section 12(UR)
# DSEC12  = '[513:640,1:1024]'   / data section 12(UR)
# TSEC12  = '[513:640,1:1024]'   / trim section 12(UR)
# ASEC13  = '[385:512,1:1024]'   / amplifier section 13(UR)
# BSEC13  = '        '           / bias section 13(UR)
# CSEC13  = '[385:512,1:1024]'   / ccd section 13(UR)
# DSEC13  = '[385:512,1:1024]'   / data section 13(UR)
# TSEC13  = '[385:512,1:1024]'   / trim section 13(UR)
# ASEC14  = '[257:384,1:1024]'   / amplifier section 14(UR)
# BSEC14  = '        '           / bias section 14(UR)
# CSEC14  = '[257:384,1:1024]'   / ccd section 14(UR)
# DSEC14  = '[257:384,1:1024]'   / data section 14(UR)
# TSEC14  = '[257:384,1:1024]'   / trim section 14(UR)
# ASEC15  = '[129:256,1:1024]'   / amplifier section 15(UR)
# BSEC15  = '        '           / bias section 15(UR)
# CSEC15  = '[129:256,1:1024]'   / ccd section 15(UR)
# DSEC15  = '[129:256,1:1024]'   / data section 15(UR)
# TSEC15  = '[129:256,1:1024]'   / trim section 15(UR)
# ASEC16  = '[1:128,1:1024]'     / amplifier section 16(UR)
# BSEC16  = '        '           / bias section 16(UR)
# CSEC16  = '[1:128,1:1024]'     / ccd section 16(UR)
# DSEC16  = '[1:128,1:1024]'     / data section 16(UR)
# TSEC16  = '[1:128,1:1024]'     / trim section 16(UR)
# ROISEC  = '[1:2048,1:1536]'    / roi section
# DEID_1  = 'Hawaii-IIb_47'      / detector ID_number
# DETSER_1= '47      '           / detector serial number
# FPA     = 'TSPEC_SPEC'         / focal plan array
# DHEINF  = 'SDSU, Gen-III'      / controller info
# QUADRANT= '3 and 4 '           / quadrants in use
# VOFF1   =                 -0.9 / video ch.1 offset
# VOFF9   =                 -0.9 / video ch.9 offset
# VBGAT_A =                  3.5 / bias gate A
# VBGAT_B =                  3.5 / bias gate B
# VBPOW_A =                   5. / bias power A
# VBPOW_B =                   5. / bias power B
# VRESET_A=                 0.75 / v reset A
# VRESET_B=                 0.75 / v reset B
# DSUB_A  =                   0. / d sub A
# DSUB_B  =                   0. / d sub B
# VDDA_A  =                   5. / analog power A
# VDDA_B  =                   5. / analog power B
# CATNAME = 'J1831+2656'         / catalog name
# DATE    = '127     '           / date of obs
# TIME    = '09:57:49.9'         / time of obs
# LST     = '17:10:20.1'         / lst
# RA      = '18:31:16.18'        / ra
# DEC     = '+26:55:56.1'        / dec
# HA      = 'E01:21:52.5'        / ha
# AIRMASS =                1.056 / airmass
# TELFOCUS=                  39. / focus position mm
# CASS_ROT=                90.02 / cass rotation angle
# TELID   = '200     '           / telescope ID
# LODVER  = '/home/arcview/TSPEC/SPEC/config/DETECTOR/tim.lod' / timing board lod
# GAIN    =                  3.8 / e-/adu
# DISPAXIS= '1       '           / iraf dispersion axis

# %%
open_file = fits.open(files[54])
header_file = open_file[0].header
data_b = open_file['PRIMARY'].data.astype(float)
plot_data(data_b)
print(repr(header_file))
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 2048 / length of data axis 1
# NAXIS2  =                 1024 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format defined in Astronomy and
# COMMENT   Astrophysics Supplement Series v44/p363, v44/p371, v73/p359, v73/p365.
# COMMENT   Contact the NASA Science Office of Standards and Technology for the
# COMMENT   FITS Definition document #100 and other FITS information.
# OBJECT  = 'B eclipse'          / object name
# SOFTVER = '4.0     '           / software version
# HDR_REV = '4.3     '           / header revision
# OBSERVER= 'xanderberyl'        / observer
# OBSTYPE = 'object  '           / observation type
# UTSHUT  = '2023-05-07T09:35:13.463' / UT shutter open
# COADDS  =                    1 / number of coadded images
# FSAMPLE =                   16 / number of fowler samples
# EXPTIME =                 300. / exposure time
# ACCTIME = '        '           / accumulated exp time (sur)
# NAMPSXY = '9 8     '           / number of amplifiers in x y
# ASEC1   = '[1025:2048,1:128]'  / amplifier section 1(LL)
# BSEC1   = '        '           / bias section 1(LL)
# CSEC1   = '[1025:2048,1:128]'  / ccd section 1(LL)
# DSEC1   = '[1025:2048,1:128]'  / data section 1(LL)
# TSEC1   = '[1025:2048,1:128]'  / trim section 1(LL)
# ASEC2   = '[1025:2048,129:256]' / amplifier section 2(LL)
# BSEC2   = '        '           / bias section 2(LL)
# CSEC2   = '[1025:2048,129:256]' / ccd section 2(LL)
# DSEC2   = '[1025:2048,129:256]' / data section 2(LL)
# TSEC2   = '[1025:2048,129:256]' / trim section 2(LL)
# ASEC3   = '[1025:2048,257:384]' / amplifier section 3(LL)
# BSEC3   = '        '           / bias section 3(LL)
# CSEC3   = '[1025:2048,257:384]' / ccd section 3(LL)
# DSEC3   = '[1025:2048,257:384]' / data section 3(LL)
# TSEC3   = '[1025:2048,257:384]' / trim section 3(LL)
# ASEC4   = '[1025:2048,385:512]' / amplifier section 4(LL)
# BSEC4   = '        '           / bias section 4(LL)
# CSEC4   = '[1025:2048,385:512]' / ccd section 4(LL)
# DSEC4   = '[1025:2048,385:512]' / data section 4(LL)
# TSEC4   = '[1025:2048,385:512]' / trim section 4(LL)
# ASEC5   = '[1025:2048,513:640]' / amplifier section 5(LL)
# BSEC5   = '        '           / bias section 5(LL)
# CSEC5   = '[1025:2048,513:640]' / ccd section 5(LL)
# DSEC5   = '[1025:2048,513:640]' / data section 5(LL)
# TSEC5   = '[1025:2048,513:640]' / trim section 5(LL)
# ASEC6   = '[1025:2048,641:768]' / amplifier section 6(LL)
# BSEC6   = '        '           / bias section 6(LL)
# CSEC6   = '[1025:2048,641:768]' / ccd section 6(LL)
# DSEC6   = '[1025:2048,641:768]' / data section 6(LL)
# TSEC6   = '[1025:2048,641:768]' / trim section 6(LL)
# ASEC7   = '[1025:2048,769:896]' / amplifier section 7(LL)
# BSEC7   = '        '           / bias section 7(LL)
# CSEC7   = '[1025:2048,769:896]' / ccd section 7(LL)
# DSEC7   = '[1025:2048,769:896]' / data section 7(LL)
# TSEC7   = '[1025:2048,769:896]' / trim section 7(LL)
# ASEC8   = '[1025:2048,897:1024]' / amplifier section 8(LL)
# BSEC8   = '        '           / bias section 8(LL)
# CSEC8   = '[1025:2048,897:1024]' / ccd section 8(LL)
# DSEC8   = '[1025:2048,897:1024]' / data section 8(LL)
# TSEC8   = '[1025:2048,897:1024]' / trim section 8(LL)
# ASEC9   = '[897:1024,1:1024]'  / amplifier section 9(UR)
# BSEC9   = '        '           / bias section 9(UR)
# CSEC9   = '[897:1024,1:1024]'  / ccd section 9(UR)
# DSEC9   = '[897:1024,1:1024]'  / data section 9(UR)
# TSEC9   = '[897:1024,1:1024]'  / trim section 9(UR)
# ASEC10  = '[769:896,1:1024]'   / amplifier section 10(UR)
# BSEC10  = '        '           / bias section 10(UR)
# CSEC10  = '[769:896,1:1024]'   / ccd section 10(UR)
# DSEC10  = '[769:896,1:1024]'   / data section 10(UR)
# TSEC10  = '[769:896,1:1024]'   / trim section 10(UR)
# ASEC11  = '[641:768,1:1024]'   / amplifier section 11(UR)
# BSEC11  = '        '           / bias section 11(UR)
# CSEC11  = '[641:768,1:1024]'   / ccd section 11(UR)
# DSEC11  = '[641:768,1:1024]'   / data section 11(UR)
# TSEC11  = '[641:768,1:1024]'   / trim section 11(UR)
# ASEC12  = '[513:640,1:1024]'   / amplifier section 12(UR)
# BSEC12  = '        '           / bias section 12(UR)
# CSEC12  = '[513:640,1:1024]'   / ccd section 12(UR)
# DSEC12  = '[513:640,1:1024]'   / data section 12(UR)
# TSEC12  = '[513:640,1:1024]'   / trim section 12(UR)
# ASEC13  = '[385:512,1:1024]'   / amplifier section 13(UR)
# BSEC13  = '        '           / bias section 13(UR)
# CSEC13  = '[385:512,1:1024]'   / ccd section 13(UR)
# DSEC13  = '[385:512,1:1024]'   / data section 13(UR)
# TSEC13  = '[385:512,1:1024]'   / trim section 13(UR)
# ASEC14  = '[257:384,1:1024]'   / amplifier section 14(UR)
# BSEC14  = '        '           / bias section 14(UR)
# CSEC14  = '[257:384,1:1024]'   / ccd section 14(UR)
# DSEC14  = '[257:384,1:1024]'   / data section 14(UR)
# TSEC14  = '[257:384,1:1024]'   / trim section 14(UR)
# ASEC15  = '[129:256,1:1024]'   / amplifier section 15(UR)
# BSEC15  = '        '           / bias section 15(UR)
# CSEC15  = '[129:256,1:1024]'   / ccd section 15(UR)
# DSEC15  = '[129:256,1:1024]'   / data section 15(UR)
# TSEC15  = '[129:256,1:1024]'   / trim section 15(UR)
# ASEC16  = '[1:128,1:1024]'     / amplifier section 16(UR)
# BSEC16  = '        '           / bias section 16(UR)
# CSEC16  = '[1:128,1:1024]'     / ccd section 16(UR)
# DSEC16  = '[1:128,1:1024]'     / data section 16(UR)
# TSEC16  = '[1:128,1:1024]'     / trim section 16(UR)
# ROISEC  = '[1:2048,1:1536]'    / roi section
# DEID_1  = 'Hawaii-IIb_47'      / detector ID_number
# DETSER_1= '47      '           / detector serial number
# FPA     = 'TSPEC_SPEC'         / focal plan array
# DHEINF  = 'SDSU, Gen-III'      / controller info
# QUADRANT= '3 and 4 '           / quadrants in use
# VOFF1   =                 -0.9 / video ch.1 offset
# VOFF9   =                 -0.9 / video ch.9 offset
# VBGAT_A =                  3.5 / bias gate A
# VBGAT_B =                  3.5 / bias gate B
# VBPOW_A =                   5. / bias power A
# VBPOW_B =                   5. / bias power B
# VRESET_A=                 0.75 / v reset A
# VRESET_B=                 0.75 / v reset B
# DSUB_A  =                   0. / d sub A
# DSUB_B  =                   0. / d sub B
# VDDA_A  =                   5. / analog power A
# VDDA_B  =                   5. / analog power B
# CATNAME = 'J1831+2656'         / catalog name
# DATE    = '127     '           / date of obs
# TIME    = '09:35:13.5'         / time of obs
# LST     = '16:47:40.0'         / lst
# RA      = '18:31:16.24'        / ra
# DEC     = '+26:55:56.1'        / dec
# HA      = 'E01:44:32.7'        / ha
# AIRMASS =                 1.09 / airmass
# TELFOCUS=                  39. / focus position mm
# CASS_ROT=                90.02 / cass rotation angle
# TELID   = '200     '           / telescope ID
# LODVER  = '/home/arcview/TSPEC/SPEC/config/DETECTOR/tim.lod' / timing board lod
# GAIN    =                  3.8 / e-/adu
# DISPAXIS= '1       '           / iraf dispersion axis

# %%
plot_data(data_a - data_b)
